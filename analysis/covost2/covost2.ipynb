# %%
import itertools
import json
from pathlib import Path

import pandas as pd

# %%
BASE_DIR = "../../evaluation/output_evals/covost2"
DIRECTION_PAIRS = ['de_en','en_de', 'en_es','en_fr','en_it','en_nl','en_pt',
                    'en_zh','es_en',
                    'it_en','pt_en',
                    'zh_en']
SYSTEM_NAMES = ["aya_canary-v2", "aya_owsm4.0-ctc","aya_seamlessm4t","aya_whisper",
                "canary-v2","desta2-8b","gemma_canary-v2","gemma_owsm4.0-ctc","gemma_seamlessm4t", "gemma_whisper",
                "owsm4.0-ctc","phi4multimodal","qwen2audio-7b","seamlessm4t",
                "tower_canary-v2", "tower_owsm4.0-ctc","tower_seamlessm4t","tower_whisper",
                "voxtral-small-24b","whisper", "spirelm", "qwen3omni"]

# %%
def load_results_summaries(base_dir, direction_pairs, system_names):
    """
    Loads all result summaries from a directory structure.

    Args:
        base_dir (str or Path): The base directory for the evaluation outputs.
        direction_pairs (list): A list of language direction strings (e.g., 'en_de').
        system_names (list): A list of system name strings.

    Returns:
        dict: A nested dictionary containing the loaded data, structured as
              {direction: {system: [results]}}.
    """
    base_path = Path(base_dir)
    all_results = {}

    # Use itertools.product to cleanly iterate over all combinations
    for direction, system in itertools.product(direction_pairs, system_names):
        summary_path = base_path / system / direction / 'results_summary.jsonl'
        
        # Initialize the nested dictionary structure
        if direction not in all_results:
            all_results[direction] = {}

        try:
            with summary_path.open('r', encoding='utf-8') as f:
                all_results[direction][system] = [json.loads(line) for line in f]
                
        except FileNotFoundError:
            print(f"Warning: File not found, skipping: {summary_path}")
            all_results[direction][system] = None # Or [] if you prefer an empty list
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in {summary_path}: {e}")
            all_results[direction][system] = None

    return all_results

# %%
def convert_results_to_dataframe(results_data):
    """
    Converts the nested dictionary of results into a single pandas DataFrame.

    Each row corresponds to a single entry, with 'direction' and 'system'
    columns added, and all 'metrics' unpacked into separate columns.
    """
    all_records = []
    for direction, systems in results_data.items():
        for system, records in systems.items():
            if records is None:
                continue
            for record in records:
                # Separate metrics from the record
                metrics = record.pop("metrics", {})  # safely get metrics
                # Merge everything into one flat dict
                flat_record = {
                    "direction": direction,
                    "system": system,
                    **record,
                    **metrics,  # unpack metrics into top-level keys
                }
                all_records.append(flat_record)

    if not all_records:
        print("No records were found to create a DataFrame.")
        return pd.DataFrame()

    df = pd.DataFrame(all_records)

    # Put identifying info up front
    original_cols = [c for c in df.columns if c not in ["direction", "system"]]
    df = df[["direction", "system"] + original_cols]

    return df

# %%
results = load_results_summaries(BASE_DIR, DIRECTION_PAIRS, SYSTEM_NAMES)
# Out:
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/spirelm/de_en/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_de/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_es/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_fr/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_it/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_nl/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_pt/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/whisper/en_zh/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/spirelm/es_en/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/spirelm/it_en/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/spirelm/pt_en/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/covost2/spirelm/zh_en/results_summary.jsonl

# %%
df = convert_results_to_dataframe(results)

# %%
df
# Out:
#     direction             system  SacreBLEU     chrF  XCOMET  XCOMET-QE  \
# 0       de_en      aya_canary-v2    36.1079  62.0040  0.9087     0.8840
# 1       de_en    aya_owsm4.0-ctc    34.6654  60.8378  0.8866     0.8574
# 2       de_en    aya_seamlessm4t    36.0473  61.9710  0.9072     0.8847
# 3       de_en        aya_whisper    35.4969  61.5708  0.9060     0.8807
# 4       de_en          canary-v2    38.4851  62.3390  0.8699     0.8516
# ..        ...                ...        ...      ...     ...        ...
# 247     zh_en  tower_seamlessm4t    23.1993  51.9480  0.7878     0.8382
# 248     zh_en      tower_whisper    22.0192  50.1184  0.7447     0.7910
# 249     zh_en  voxtral-small-24b    11.4049  39.9440  0.6633     0.7342
# 250     zh_en            whisper    12.6007  38.2573  0.5899     0.6502
# 251     zh_en          qwen3omni    26.4893  55.2676  0.8370     0.8823
#
#      RefMetricX_24  QEMetricX_24  LinguaPy  RefMetricX_24-Strict-linguapy  \
# 0           3.5598        3.4758    4.0486                         4.4073
# 1           4.0903        3.9701    4.1448                         4.9305
# 2           3.6159        3.5270    4.1374                         4.4595
# 3           3.5921        3.5197    4.1966                         4.4707
# 4           5.0626        4.8247    4.6629                         5.9807
# ..             ...           ...       ...                            ...
# 247         4.6224        3.4815   10.5145                         6.6348
# 248         5.4877        4.3364    9.0853                         7.1987
# 249         7.4391        5.4210   11.9845                         9.3724
# 250         9.4696        7.9533   11.6782                        11.3830
# 251         3.4101        2.3620   11.9437                         5.7599
#
#      QEMetricX_24-Strict-linguapy  XCOMET-Strict-linguapy  \
# 0                          4.3276                  0.8730
# 1                          4.8147                  0.8513
# 2                          4.3784                  0.8717
# 3                          4.4001                  0.8696
# 4                          5.7577                  0.8307
# ..                            ...                     ...
# 247                        5.7066                  0.7176
# 248                        6.2083                  0.6867
# 249                        7.7433                  0.5972
# 250                       10.0767                  0.5302
# 251                        4.9838                  0.7542
#
#      XCOMET-QE-Strict-linguapy
# 0                       0.8490
# 1                       0.8232
# 2                       0.8497
# 3                       0.8453
# 4                       0.8127
# ..                         ...
# 247                     0.7557
# 248                     0.7237
# 249                     0.6514
# 250                     0.5785
# 251                     0.7854
#
# [252 rows x 13 columns]

# %%
for pair in DIRECTION_PAIRS:
    sub_df = df[df['direction']==pair]
    sub_df.to_csv(f"covost2_{pair}.csv",index=False)

# %%
sub_df
# Out:
#     direction             system  SacreBLEU     chrF  XCOMET  XCOMET-QE  \
# 231     zh_en      aya_canary-v2     0.1006  11.0016  0.1818     0.1890
# 232     zh_en    aya_owsm4.0-ctc    18.3667  48.8463  0.7681     0.8149
# 233     zh_en    aya_seamlessm4t    18.6413  49.4385  0.7855     0.8312
# 234     zh_en        aya_whisper    17.4938  47.9232  0.7382     0.7803
# 235     zh_en          canary-v2     0.1795  11.5919  0.1655     0.1727
# 236     zh_en          desta2-8b    11.8349  39.5873  0.5251     0.5420
# 237     zh_en    gemma_canary-v2     0.1766   9.2491  0.1531     0.1660
# 238     zh_en  gemma_owsm4.0-ctc    18.8148  48.0333  0.7465     0.8009
# 239     zh_en  gemma_seamlessm4t    19.8080  48.7851  0.7691     0.8225
# 240     zh_en      gemma_whisper    18.5630  47.1890  0.7272     0.7763
# 241     zh_en        owsm4.0-ctc     3.7058  17.0391  0.2494     0.2795
# 242     zh_en     phi4multimodal    18.7820  39.5620  0.7659     0.8424
# 243     zh_en      qwen2audio-7b    19.2960  47.1774  0.7294     0.7867
# 244     zh_en        seamlessm4t    21.8881  47.7455  0.7295     0.7939
# 245     zh_en    tower_canary-v2     0.0509   7.5924  0.1644     0.1793
# 246     zh_en  tower_owsm4.0-ctc    22.2452  51.1634  0.7704     0.8210
# 247     zh_en  tower_seamlessm4t    23.1993  51.9480  0.7878     0.8382
# 248     zh_en      tower_whisper    22.0192  50.1184  0.7447     0.7910
# 249     zh_en  voxtral-small-24b    11.4049  39.9440  0.6633     0.7342
# 250     zh_en            whisper    12.6007  38.2573  0.5899     0.6502
# 251     zh_en          qwen3omni    26.4893  55.2676  0.8370     0.8823
#
#      RefMetricX_24  QEMetricX_24  LinguaPy  RefMetricX_24-Strict-linguapy  \
# 231        17.0633       15.9407   11.8007                        17.6932
# 232         5.1468        3.9381    8.8199                         6.8693
# 233         4.6369        3.5303    8.7178                         6.3338
# 234         5.4819        4.3090    8.0849                         7.0179
# 235        20.2277       18.9446   55.3287                        23.5498
# 236         9.2555        7.4511    5.1654                        10.0876
# 237        19.7566       18.2784   60.0857                        23.4481
# 238         5.6509        4.3147   10.2491                         7.5543
# 239         4.9729        3.7155   10.2695                         6.9278
# 240         5.8652        4.5816    9.2691                         7.5320
# 241        18.3109       17.5520   22.1519                        20.2574
# 242         5.8845        4.5601   38.4238                        12.6944
# 243         5.6995        4.0154   12.5970                         7.8198
# 244         6.7604        5.1909    5.9412                         7.7450
# 245        19.2477       17.9197   71.8865                        23.1286
# 246         5.1971        3.8973   10.5962                         7.2328
# 247         4.6224        3.4815   10.5145                         6.6348
# 248         5.4877        4.3364    9.0853                         7.1987
# 249         7.4391        5.4210   11.9845                         9.3724
# 250         9.4696        7.9533   11.6782                        11.3830
# 251         3.4101        2.3620   11.9437                         5.7599
#
#      QEMetricX_24-Strict-linguapy  XCOMET-Strict-linguapy  \
# 231                       16.7437                  0.1619
# 232                        5.8224                  0.7053
# 233                        5.3900                  0.7261
# 234                        5.9917                  0.6851
# 235                       23.1620                  0.0595
# 236                        8.4192                  0.5037
# 237                       22.9782                  0.0578
# 238                        6.4403                  0.6779
# 239                        5.8571                  0.7021
# 240                        6.4332                  0.6698
# 241                       19.7616                  0.1861
# 242                       11.8230                  0.4819
# 243                        6.4984                  0.6551
# 244                        6.3393                  0.6918
# 245                       22.9997                  0.0438
# 246                        6.1648                  0.6965
# 247                        5.7066                  0.7176
# 248                        6.2083                  0.6867
# 249                        7.7433                  0.5972
# 250                       10.0767                  0.5302
# 251                        4.9838                  0.7542
#
#      XCOMET-QE-Strict-linguapy
# 231                     0.1677
# 232                     0.7433
# 233                     0.7626
# 234                     0.7197
# 235                     0.0613
# 236                     0.5168
# 237                     0.0602
# 238                     0.7199
# 239                     0.7428
# 240                     0.7094
# 241                     0.2043
# 242                     0.5144
# 243                     0.6934
# 244                     0.7477
# 245                     0.0448
# 246                     0.7340
# 247                     0.7557
# 248                     0.7237
# 249                     0.6514
# 250                     0.5785
# 251                     0.7854

# %%
import glob
# Read all CSV files for covost2
csv_files = glob.glob("covost2_*.csv")
all_dfs = []

for file in csv_files:
    df_temp = pd.read_csv(file)
    all_dfs.append(df_temp)
# Combine all dataframes
df = pd.concat(all_dfs, ignore_index=True)

# Define the desired column order
desired_order = ['en_de', 'en_es', 'en_fr','en_it', 'en_nl', 'en_pt',
            'en_zh', 'de_en', 'es_en', 'it_en', 'pt_en', 'zh_en']

# Get all metric columns (exclude direction and system)
metric_columns = [col for col in df.columns if col not in ['direction', 'system']]

print("Available metrics:", metric_columns)

# Create pivot tables for each metric with specified column order
pivot_tables = {}

for metric in metric_columns:
    pivot_df = df.pivot_table(
        index='system',
        columns='direction', 
        values=metric,
        aggfunc='mean'
    )
    
    # Reorder columns to match desired order
    # Only include columns that actually exist in the data
    available_columns = [col for col in desired_order if col in pivot_df.columns]
    pivot_df = pivot_df[available_columns]
    
    # # Add average column
    # pivot_df['average'] = pivot_df.mean(axis=1)
    
    # # Sort by average
    # pivot_df = pivot_df.sort_values('average', ascending=False)
    
    pivot_tables[metric] = pivot_df
    
    # Save each pivot table to CSV
    pivot_df.to_csv(f"covost2_{metric}_pivot.csv")
    
    print(f"\n=== {metric} ===")
    print(pivot_df)
# Out:
# Available metrics: ['en_de', 'en_zh', 'de_en', 'es_en', 'it_en', 'pt_en', 'zh_en', 'en_es', 'en_fr', 'en_it', 'en_nl', 'en_pt', 'SacreBLEU', 'chrF', 'XCOMET', 'XCOMET-QE', 'RefMetricX_24', 'QEMetricX_24', 'LinguaPy', 'RefMetricX_24-Strict-linguapy', 'QEMetricX_24-Strict-linguapy', 'XCOMET-Strict-linguapy', 'XCOMET-QE-Strict-linguapy']
#
# === en_de ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === en_zh ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === de_en ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === es_en ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === it_en ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === pt_en ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === zh_en ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === en_es ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === en_fr ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === en_it ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === en_nl ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === en_pt ===
# Empty DataFrame
# Columns: []
# Index: []
#
# === SacreBLEU ===
# direction            en_de    en_zh    de_en    es_en    it_en    pt_en  \
# system
# aya_canary-v2      32.7329  36.4145  36.1079  39.1207  33.4437  47.2553
# aya_owsm4.0-ctc    31.5364  34.1466  34.6654  37.5482  31.4639  47.6917
# aya_seamlessm4t    34.7268  37.7321  36.0473  38.9322  35.3301  49.2695
# aya_whisper        32.0546  35.0977  35.4969  38.5922  32.9242  48.4551
# canary-v2          33.0355   0.1581  38.4851  41.7368  39.0678  48.7816
# desta2-8b          10.3392   8.8600  24.0921  26.7954  18.4489  36.4572
# gemma_canary-v2    30.8613  35.3387  35.2458  25.3690  34.0260  46.4020
# gemma_owsm4.0-ctc  30.1412  34.5679  34.1250  36.5686  31.6293  47.1356
# gemma_seamlessm4t  32.5072  36.5765  35.3836  38.0114  34.7642  48.4264
# gemma_whisper      29.9175  34.0066  34.9104  37.4786  32.9143  47.3474
# owsm4.0-ctc        27.9990  35.1534  21.9400  31.5699  26.7353  34.1257
# phi4multimodal     27.4235  41.5561  37.5324  37.3035  38.9802  53.2566
# voxtral-small-24b  60.3292  37.2069  64.8135  67.5911  65.0450  72.7417
# whisper                NaN      NaN  58.3345  64.2284  61.3223  70.1376
#
# direction            zh_en
# system
# aya_canary-v2      11.0016
# aya_owsm4.0-ctc    48.8463
# aya_seamlessm4t    49.4385
# aya_whisper        47.9232
# canary-v2          11.5919
# desta2-8b          39.5873
# gemma_canary-v2     9.2491
# gemma_owsm4.0-ctc  48.0333
# gemma_seamlessm4t  48.7851
# gemma_whisper      47.1890
# owsm4.0-ctc        17.0391
# phi4multimodal     39.5620
# qwen2audio-7b      47.1774
# qwen3omni          55.2676
# seamlessm4t        47.7455
# spirelm                NaN
# tower_canary-v2     7.5924
# tower_owsm4.0-ctc  51.1634
# tower_seamlessm4t  51.9480
# tower_whisper      50.1184
# voxtral-small-24b  39.9440
# whisper            38.2573
#
# === XCOMET ===
# direction           en_de   en_zh   de_en   es_en   it_en   pt_en   zh_en
# system
# aya_canary-v2      0.9307  0.8785  0.9087  0.8997  0.8759  0.8732  0.1818
# aya_owsm4.0-ctc    0.9181  0.8598  0.8866  0.8805  0.8549  0.8930  0.7681
# aya_seamlessm4t    0.9494  0.8997  0.9072  0.8963  0.8779  0.9017  0.7855
# aya_whisper        0.9168  0.8626  0.9060  0.8913  0.8674  0.9078  0.7382
# canary-v2          0.9170  0.9069  0.8699  0.8842  0.8517  0.8416  0.1655
# desta2-8b          0.7939  0.5231  0.6889  0.6997  0.6113  0.7150  0.5251
# gemma_canary-v2    0.9253  0.8715  0.9009  0.8960  0.8701  0.8657  0.1531
# gemma_owsm4.0-ctc  0.9114  0.8539  0.8761  0.8760  0.8475  0.8877  0.7465
# gemma_seamlessm4t  0.9450  0.8950  0.8997  0.8934  0.8731  0.8966  0.7691
# gemma_whisper      0.9108  0.8563  0.8983  0.8878  0.8636  0.9018  0.7272
# owsm4.0-ctc        0.8284  0.7405  0.5299  0.6822  0.5888  0.6541  0.2494
# phi4multimodal     0.8912  0.8672  0.8952  0.8911  0.8738  0.9036  0.7659
# qwen2audio-7b      0.8665  0.8205  0.7669  0.8159  0.7701  0.8078  0.7294
# qwen3omni          0.9401  0.8997  0.9174  0.9127  0.8930  0.9148  0.8370
# seamlessm4t        0.9425  0.8538  0.8814  0.8878  0.8586  0.8937  0.7295
# spirelm            0.7565  0.6519     NaN     NaN     NaN     NaN     NaN
# tower_canary-v2    0.9305  0.8848  0.9101  0.9013  0.8796  0.8733  0.1644
# tower_owsm4.0-ctc  0.9175  0.8666  0.8855  0.8821  0.8581  0.8920  0.7704
# tower_seamlessm4t  0.9495  0.9075  0.9073  0.8983  0.8815  0.9033  0.7878
# tower_whisper      0.9165  0.8686  0.9066  0.8935  0.8715  0.9089  0.7447
# voxtral-small-24b  0.9206  0.8706  0.9006  0.9059  0.8760  0.9055  0.6633
# whisper               NaN     NaN  0.8162  0.8452  0.7991  0.8761  0.5899
#
# === XCOMET-QE ===
# direction           en_de   en_es   en_fr   en_it   en_nl   en_pt   en_zh  \
# system
# aya_canary-v2      0.9354  0.8827  0.8426  0.8614  0.9119  0.8875  0.8653
# tower_owsm4.0-ctc  0.8603  0.8646  0.8313  0.8520  0.8210
# tower_seamlessm4t  0.8868  0.8857  0.8622  0.8697  0.8382
# tower_whisper      0.8839  0.8772  0.8483  0.8720  0.7910
# voxtral-small-24b  0.8778  0.8910  0.8534  0.8689  0.7342
# whisper            0.7899  0.8305  0.7775  0.8364  0.6502
#
# === RefMetricX_24 ===
# direction           en_de    en_zh    de_en   es_en    it_en   pt_en    zh_en
# system
# aya_canary-v2      1.9774   2.0578   3.5598  3.6525   3.7772  3.6239  17.0633
# aya_owsm4.0-ctc    2.3417   2.2917   4.0903  4.1215   4.2403  3.1823   5.1468
# aya_seamlessm4t    1.5221   1.7906   3.6159  3.7025   3.7615  3.0072   4.6369
# aya_whisper        2.2223   2.2030   3.5921  3.7959   3.8843  2.8218   5.4819
# canary-v2          2.6202  16.0486   5.0626  4.2790   4.6333  4.7286  20.2277
# desta2-8b          4.8972   6.4644   7.3620  6.9666   8.1145  6.0087   9.2555
# gemma_canary-v2    2.0887   2.0899   3.8335  3.7837   3.9526  3.8258  19.7566
# gemma_owsm4.0-ctc  2.4869   2.3338   4.4580  4.2909   4.4874  3.3791   5.6509
# gemma_seamlessm4t  1.6253   1.8073   3.8929  3.8182   3.9224  3.1417   4.9729
# gemma_whisper      2.3291   2.2500   3.8737  3.9176   4.0547  2.9498   5.8652
# owsm4.0-ctc        6.1110   4.7475  13.2495  9.4484  10.9060  9.8547  18.3109
# phi4multimodal     5.9176   3.3334   4.7501  5.5062   4.8344  3.2974   5.8845
# qwen2audio-7b      3.8182   2.7911   6.7382  5.5825   6.1742  5.3327   5.6995
# qwen3omni          1.7082   1.7169   3.3581  3.3430   3.4717  2.6694   3.4101
# seamlessm4t        1.8641   2.9216   4.5034  4.1098   4.3925  3.2940   6.7604
# spirelm            5.6606   4.6751      NaN     NaN      NaN     NaN      NaN
# tower_canary-v2    2.0081   1.9734   3.5278  3.6117   3.7250  3.6375  19.2477
# tower_owsm4.0-ctc  2.4116   2.2523   4.1546  4.1262   4.2351  3.1828   5.1971
# tower_seamlessm4t  1.5335   1.6895   3.5984  3.6697   3.6733  2.9090   4.6224
# tower_whisper      2.2409   2.1380   3.5691  3.7396   3.7966  2.7474   5.4877
# voxtral-small-24b  2.0547   2.1118   3.6979  3.4854   3.7475  2.8445   7.4391
# whisper               NaN      NaN   6.4212  5.2532   5.8915  3.7395   9.4696
#
# === QEMetricX_24 ===
# direction           en_de    en_es    en_fr    en_it    en_nl    en_pt  \
# system
# aya_canary-v2      1.9504   3.1399   3.3106   3.2325   3.0437   3.6110
# aya_owsm4.0-ctc    2.3163   3.6458   3.7901   3.7401   3.5255   4.1975
# aya_seamlessm4t    1.5135   2.5626   2.7399   2.6815   2.5045   3.0228
# aya_whisper        2.2029   3.7578   3.6641   3.5914   3.3713   4.0179
# canary-v2          2.5327   3.7372   4.0009   3.8525   3.6381   4.2052
# desta2-8b          4.7861   6.5456   6.7018   7.0937   6.6933   7.3977
# gemma_canary-v2    2.0168   3.1342   3.3339   3.2433   3.0944   3.7179
# tower_canary-v2      0.2060   4.5815   4.7122   5.7424  2.7094  71.8865
# tower_owsm4.0-ctc    0.2125   4.8183   4.7803   5.6977  2.3614  10.5962
# tower_seamlessm4t    0.1867   4.8035   4.4777   5.4407  2.1377  10.5145
# tower_whisper        0.2189   4.7739   4.7349   5.9323  2.2620   9.0853
# voxtral-small-24b    0.5087   5.3290   4.7349   6.2228  2.3863  11.9845
# whisper                 NaN   5.5510   5.1206   6.3121  2.6348  11.6782
#
# === RefMetricX_24-Strict-linguapy ===
# direction           en_de    en_zh    de_en    es_en    it_en    pt_en  \
# system
# aya_canary-v2      2.2923   2.1378   4.4073   4.5215   4.7328   4.0512
# aya_owsm4.0-ctc    2.6593   2.4381   4.9305   4.9879   5.1499   3.6210
# aya_seamlessm4t    1.8387   1.8614   4.4595   4.5443   4.6563   3.4193
# aya_whisper        2.5502   2.3048   4.4707   4.6909   4.8327   3.2865
# canary-v2          3.0315  25.0000   5.9807   5.1558   5.7580   5.2065
# desta2-8b          5.2555  12.0648   8.1055   7.5539   8.6425   6.4180
# gemma_canary-v2    2.4005   2.1310   4.7726   4.7345   5.0965   4.2634
# gemma_owsm4.0-ctc  2.7677   2.3677   5.3900   5.2291   5.6491   3.8619
# gemma_seamlessm4t  1.9207   1.8362   4.8182   4.7171   4.9817   3.5642
# gemma_whisper      2.6308   2.2821   4.8225   4.8975   5.2317   3.4344
# owsm4.0-ctc        6.5249   4.8105  14.2823  10.3810  12.0949  10.4366
# phi4multimodal     9.1055   5.3844   6.9298   7.6113   6.5275   4.0288
# qwen2audio-7b      4.3960   2.8942   7.7034   6.4637   7.3504   5.8909
# qwen3omni          2.0777   1.7577   4.3705   4.3577   4.7183   3.1191
# seamlessm4t        2.1983   2.9559   5.3524   4.9384   5.1101   3.6905
# spirelm            6.0061   4.6826      NaN      NaN      NaN      NaN
# tower_canary-v2    2.3602   2.0114   4.4707   4.5625   4.9202   4.0987
# tower_owsm4.0-ctc  2.7527   2.2886   5.1062   5.0390   5.4025   3.6665
# tower_seamlessm4t  1.8934   1.7254   4.5637   4.5511   4.7926   3.3417
# tower_whisper      2.5961   2.1748   4.5538   4.6942   5.0312   3.2366
# voxtral-small-24b  2.4951   2.1848   4.7785   4.4500   5.0313   3.3428
# whisper               NaN      NaN   7.4203   6.1836   7.1011   4.2881
#
# direction            zh_en
# system
# aya_canary-v2      17.6932
# aya_owsm4.0-ctc     6.8693
# aya_seamlessm4t     6.3338
# aya_whisper         7.0179
# canary-v2          23.5498
# desta2-8b          10.0876
# gemma_canary-v2    23.4481
# gemma_owsm4.0-ctc   7.5543
# gemma_seamlessm4t   6.9278
# gemma_whisper       7.5320
# owsm4.0-ctc        20.2574
# phi4multimodal     12.6944
# qwen2audio-7b       7.8198
# qwen3omni           5.7599
# seamlessm4t         7.7450
# spirelm                NaN
# tower_canary-v2    23.1286
# tower_owsm4.0-ctc   7.2328
# tower_seamlessm4t   6.6348
# tower_whisper       7.1987
# voxtral-small-24b   9.3724
# whisper            11.3830
#
# === QEMetricX_24-Strict-linguapy ===
# direction           en_de    en_es    en_fr    en_it    en_nl    en_pt  \
# tower_canary-v2     2.1487   4.3886  4.2812   4.6591  4.1268  22.9997
# tower_owsm4.0-ctc   2.4498   4.9809  4.7197   5.1175  3.7142   6.1648
# tower_seamlessm4t   1.8649   4.4923  4.2614   4.5385  3.5073   5.7066
# tower_whisper       2.3365   4.4768  4.4217   4.7991  3.3215   6.2083
# voxtral-small-24b   2.3718   4.6868  4.2343   4.7782  3.3780   7.7433
# whisper                NaN   7.0576  5.7859   6.7059  4.3532  10.0767
#
# === XCOMET-Strict-linguapy ===
# direction           en_de   en_zh   de_en   es_en   it_en   pt_en   zh_en
# system
# aya_canary-v2      0.9186  0.8765  0.8730  0.8633  0.8395  0.8575  0.1619
# aya_owsm4.0-ctc    0.9059  0.8566  0.8513  0.8446  0.8204  0.8767  0.7053
# aya_seamlessm4t    0.9370  0.8978  0.8717  0.8619  0.8433  0.8859  0.7261
# aya_whisper        0.9043  0.8603  0.8696  0.8545  0.8314  0.8902  0.6851
# canary-v2          0.9010  0.0000  0.8307  0.8472  0.8084  0.8236  0.0595
# desta2-8b          0.7812  0.4406  0.6613  0.6786  0.5971  0.7022  0.5037
# gemma_canary-v2    0.9132  0.8703  0.8613  0.8565  0.8270  0.8493  0.0578
# gemma_owsm4.0-ctc  0.9004  0.8528  0.8369  0.8368  0.8037  0.8693  0.6779
# gemma_seamlessm4t  0.9333  0.8940  0.8608  0.8563  0.8327  0.8805  0.7021
# gemma_whisper      0.8991  0.8552  0.8587  0.8473  0.8196  0.8833  0.6698
# owsm4.0-ctc        0.8113  0.7387  0.4868  0.6423  0.5431  0.6319  0.1861
# phi4multimodal     0.6556  0.7549  0.7796  0.7430  0.7799  0.8647  0.4819
# qwen2audio-7b      0.8403  0.8136  0.7263  0.7790  0.7235  0.7843  0.6551
# qwen3omni          0.9256  0.8982  0.8745  0.8705  0.8452  0.8973  0.7542
# seamlessm4t        0.9289  0.8525  0.8453  0.8536  0.8317  0.8789  0.6918
# spirelm            0.7434  0.6516     NaN     NaN     NaN     NaN     NaN
# tower_canary-v2    0.9165  0.8837  0.8703  0.8616  0.8340  0.8558  0.0438
# tower_owsm4.0-ctc  0.9037  0.8654  0.8456  0.8439  0.8137  0.8736  0.6965
# tower_seamlessm4t  0.9353  0.9062  0.8669  0.8619  0.8384  0.8867  0.7176
# tower_whisper      0.9025  0.8675  0.8654  0.8543  0.8251  0.8903  0.6867
# voxtral-small-24b  0.9023  0.8671  0.8547  0.8654  0.8266  0.8853  0.5972
# whisper               NaN     NaN  0.7735  0.8066  0.7525  0.8551  0.5302
#
# === XCOMET-QE-Strict-linguapy ===
# direction           en_de   en_es   en_fr   en_it   en_nl   en_pt   en_zh  \
# system
# aya_canary-v2      0.9232  0.8549  0.8306  0.8354  0.8811  0.8596  0.8631
# aya_owsm4.0-ctc    0.9108  0.8356  0.8049  0.8150  0.8644  0.8405  0.8435
# aya_seamlessm4t    0.9412  0.8801  0.8638  0.8644  0.9036  0.8852  0.8874
# aya_whisper        0.9096  0.8269  0.8095  0.8181  0.8645  0.8417  0.8475
# canary-v2          0.9074  0.8351  0.8064  0.8141  0.8566  0.8408  0.0000
# desta2-8b          0.7967  0.6861  0.5996  0.6380  0.7283  0.6909  0.4270
# gemma_canary-v2    0.9190  0.8456  0.8146  0.8219  0.8732  0.8482  0.8553
# gemma_owsm4.0-ctc  0.9071  0.8263  0.7896  0.8040  0.8555  0.8279  0.8367
# gemma_seamlessm4t  0.9381  0.8739  0.8501  0.8516  0.8965  0.8749  0.8824
# gemma_whisper      0.9051  0.8310  0.7948  0.8053  0.8563  0.8311  0.8397
# owsm4.0-ctc        0.8203  0.3704  0.4522  0.4680  0.5735  0.3248  0.7079
# phi4multimodal     0.6603  0.6247  0.4052  0.7013  0.5816  0.5578  0.7410
# qwen2audio-7b      0.8549  0.7648  0.7299  0.7427  0.7795  0.7808  0.7991
# qwen3omni          0.9298  0.8711  0.8455  0.8486  0.8846  0.8732  0.8831
# seamlessm4t        0.9344  0.8812  0.8561  0.8552  0.8890  0.8624  0.8403
# spirelm            0.7576  0.6666  0.6093  0.6399  0.6983  0.6690  0.6357
# tower_canary-v2    0.9214  0.8540  0.8265  0.8311  0.8771  0.8515  0.8662
# tower_owsm4.0-ctc  0.9088  0.8347  0.8011  0.8098  0.8602  0.8319  0.8467
# tower_seamlessm4t  0.9394  0.8812  0.8606  0.8596  0.9001  0.8791  0.8919
# tower_whisper      0.9074  0.8384  0.8077  0.8141  0.8585  0.8361  0.8491
# voxtral-small-24b  0.9087  0.8412  0.8167  0.8207  0.8642  0.8450  0.8513
# whisper               NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# direction           de_en   es_en   it_en   pt_en   zh_en
# system
# aya_canary-v2      0.8490  0.8507  0.8162  0.8186  0.1677
# aya_owsm4.0-ctc    0.8232  0.8290  0.7940  0.8389  0.7433
# aya_seamlessm4t    0.8497  0.8504  0.8237  0.8522  0.7626
# aya_whisper        0.8453  0.8400  0.8079  0.8551  0.7197
# canary-v2          0.8127  0.8335  0.7852  0.7869  0.0613
# desta2-8b          0.5868  0.6175  0.5248  0.6153  0.5168
# gemma_canary-v2    0.8388  0.8422  0.8039  0.8101  0.0602
# gemma_owsm4.0-ctc  0.8100  0.8186  0.7752  0.8313  0.7199
# gemma_seamlessm4t  0.8399  0.8428  0.8119  0.8460  0.7428
# gemma_whisper      0.8353  0.8316  0.7950  0.8481  0.7094
# owsm4.0-ctc        0.4267  0.6015  0.4905  0.5705  0.2043
# phi4multimodal     0.7631  0.7354  0.7658  0.8329  0.5144
# qwen2audio-7b      0.6914  0.7580  0.6932  0.7436  0.6934
# qwen3omni          0.8550  0.8578  0.8254  0.8629  0.7854
# seamlessm4t        0.8293  0.8429  0.8140  0.8485  0.7477
# spirelm               NaN     NaN     NaN     NaN     NaN
# tower_canary-v2    0.8496  0.8484  0.8118  0.8178  0.0448
# tower_owsm4.0-ctc  0.8214  0.8273  0.7866  0.8354  0.7340
# tower_seamlessm4t  0.8471  0.8502  0.8186  0.8541  0.7557
# tower_whisper      0.8438  0.8390  0.8015  0.8551  0.7237
# voxtral-small-24b  0.8327  0.8511  0.8036  0.8500  0.6514
# whisper            0.7480  0.7923  0.7299  0.8171  0.5785
