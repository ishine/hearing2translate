# %%
import itertools
import json
import os

import numpy as np
from pathlib import Path
import pandas as pd

# %%
BASE_DIR = f"../../evaluation/output_evals/neuroparl_st"
BASE_DIR_BASE= f"../../evaluation/output_evals/europarl_st"
DIRECTION_PAIRS = [f'en_{x}' for x in ("es","fr","it")]
DIRECTION_PAIRS
# Out:
# ['en_es', 'en_fr', 'en_it']

# %%
SYSTEM_NAMES = os.listdir(BASE_DIR)
SYSTEM_NAMES, len(SYSTEM_NAMES)
# Out:
# (['phi4multimodal',
#   'tower_owsm4.0-ctc',
#   'gemma_owsm4.0-ctc',
#   'owsm4.0-ctc',
#   'gemma_seamlessm4t',
#   'qwen2audio-7b',
#   'gemma_whisper',
#   'aya_seamlessm4t',
#   'aya_whisper',
#   'tower_canary-v2',
#   'gemini-2.5-flash',
#   'seamlessm4t',
#   'desta2-8b',
#   'aya_owsm4.0-ctc',
#   'tower_seamlessm4t',
#   'voxtral-small-24b',
#   'whisper',
#   'spirelm',
#   'canary-v2',
#   'tower_whisper',
#   'gemma_canary-v2',
#   'aya_canary-v2'],
#  22)

# %%
def load_results_summaries(base_dir, direction_pairs, system_names):
    """
    Loads all result summaries from a directory structure.

    Args:
        base_dir (str or Path): The base directory for the evaluation outputs.
        direction_pairs (list): A list of language direction strings (e.g., 'en_de').
        system_names (list): A list of system name strings.

    Returns:
        dict: A nested dictionary containing the loaded data, structured as
              {direction: {system: [results]}}.
    """
    base_path = Path(base_dir)
    all_results = {}

    # Use itertools.product to cleanly iterate over all combinations
    for direction, system in itertools.product(direction_pairs, system_names):
        summary_path = base_path / system / direction / 'results_summary.jsonl'
        
        # Initialize the nested dictionary structure
        if direction not in all_results:
            all_results[direction] = {}

        try:
            with summary_path.open('r', encoding='utf-8') as f:
                all_results[direction][system] = [json.loads(line) for line in f]
                
        except FileNotFoundError:
            print(f"Warning: File not found, skipping: {summary_path}")
            all_results[direction][system] = None # Or [] if you prefer an empty list
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in {summary_path}: {e}")
            all_results[direction][system] = None

    return all_results

# %%
def convert_results_to_dataframe(results_data):
    """
    Converts the nested dictionary of results into a single pandas DataFrame.

    Each row corresponds to a single entry, with 'direction' and 'system'
    columns added, and all 'metrics' unpacked into separate columns.
    """
    all_records = []
    for direction, systems in results_data.items():
        for system, records in systems.items():
            if records is None:
                continue
            for record in records:
                # Separate metrics from the record
                metrics = record.pop("metrics", {})  # safely get metrics
                # Merge everything into one flat dict
                flat_record = {
                    "direction": direction,
                    "system": system,
                    **record,
                    **metrics,  # unpack metrics into top-level keys
                }
                all_records.append(flat_record)

    if not all_records:
        print("No records were found to create a DataFrame.")
        return pd.DataFrame()

    df = pd.DataFrame(all_records)

    # Put identifying info up front
    original_cols = [c for c in df.columns if c not in ["direction", "system"]]
    df = df[["direction", "system"] + original_cols]

    return df

# %%
def compute_strict_scores(df):
    """
    Computes mean metric scores and strict scores grouped by (system, accent).
    
    Expects columns:
      - system
      - accent
      - xcomet_qe_score
      - metricx_qe_score
      - linguapy_score (list/tuple of [flag, lang])
    """

    # --- Aggregate by system × accent ---
    agg_cols = {
        "accuracy_ne": "mean",  # average from 0–1
        "accuracy_term": "mean",  # average from 0–1
    }

    result = (
        df.groupby(["system"])
        .agg(agg_cols)
        .reset_index()
    )

    result["accuracy_ne"] =  result["accuracy_ne"] * 100
    result["accuracy_term"] =  result["accuracy_term"] * 100

    return result

# %%
results_full = load_results_summaries(BASE_DIR, DIRECTION_PAIRS, SYSTEM_NAMES)
# Out:
# Warning: File not found, skipping: ../../evaluation/output_evals/neuroparl_st/whisper/en_es/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/neuroparl_st/whisper/en_fr/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/neuroparl_st/whisper/en_it/results_summary.jsonl

# %%
results_full_base = load_results_summaries(BASE_DIR_BASE, DIRECTION_PAIRS, SYSTEM_NAMES)
# Out:
# Warning: File not found, skipping: ../../evaluation/output_evals/europarl_st/whisper/en_es/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/europarl_st/whisper/en_fr/results_summary.jsonl
# Warning: File not found, skipping: ../../evaluation/output_evals/europarl_st/whisper/en_it/results_summary.jsonl

# %%
from collections import defaultdict
out= defaultdict(lambda: defaultdict(dict))
for lang,v in results_full_base.items():
    for model,metric in v.items():
        if not metric:
            print(f"Found None in {model}, skipping")
            continue
        out[lang][model] = [metric[0] | results_full[lang][model][0]]
# Out:
# Found None in whisper, skipping
# Found None in whisper, skipping
# Found None in whisper, skipping

# %%
out["en_es"].keys()
# Out:
# dict_keys(['phi4multimodal', 'tower_owsm4.0-ctc', 'gemma_owsm4.0-ctc', 'owsm4.0-ctc', 'gemma_seamlessm4t', 'qwen2audio-7b', 'gemma_whisper', 'aya_seamlessm4t', 'aya_whisper', 'tower_canary-v2', 'gemini-2.5-flash', 'seamlessm4t', 'desta2-8b', 'aya_owsm4.0-ctc', 'tower_seamlessm4t', 'voxtral-small-24b', 'spirelm', 'canary-v2', 'tower_whisper', 'gemma_canary-v2', 'aya_canary-v2'])

# %%
import scipy.stats as stats
df = convert_results_to_dataframe(out)
quality="QEMetricX_24-Strict-linguapy"
quality="XCOMET-QE-Strict-linguapy"
accuracy="accuracy_ci_term"
df[accuracy]


for corr in (stats.spearmanr, stats.pearsonr ,stats.kendalltau):
    print(corr.__name__, corr(df[accuracy], df[quality]))
    for lang in set(df["direction"]):
        print(corr.__name__, lang, corr(df.query(f"direction == '{lang}'")[accuracy], df.query(f"direction == '{lang}'")[quality]))
# Out:
# spearmanr SignificanceResult(statistic=np.float64(0.5981541711602963), pvalue=np.float64(2.2555164333890755e-07))
# spearmanr en_it SignificanceResult(statistic=np.float64(0.6463137723141105), pvalue=np.float64(0.0015479165935381224))
# spearmanr en_fr SignificanceResult(statistic=np.float64(0.6621183983841537), pvalue=np.float64(0.0010762495217218968))
# spearmanr en_es SignificanceResult(statistic=np.float64(0.6878857134478824), pvalue=np.float64(0.0005679649199788145))
# pearsonr PearsonRResult(statistic=np.float64(0.8592640958933517), pvalue=np.float64(2.0521568522876603e-19))
# pearsonr en_it PearsonRResult(statistic=np.float64(0.9455725195725218), pvalue=np.float64(1.0350499415644597e-10))
# pearsonr en_fr PearsonRResult(statistic=np.float64(0.9058893343420938), pvalue=np.float64(1.606402311405795e-08))
# pearsonr en_es PearsonRResult(statistic=np.float64(0.8965159129647351), pvalue=np.float64(3.812895195129821e-08))
# kendalltau SignificanceResult(statistic=np.float64(0.4183542818819319), pvalue=np.float64(1.297120864475824e-06))
# kendalltau en_it SignificanceResult(statistic=np.float64(0.4725550451288101), pvalue=np.float64(0.0027819372153893925))
# kendalltau en_fr SignificanceResult(statistic=np.float64(0.4784743764693455), pvalue=np.float64(0.002507379161578495))
# kendalltau en_es SignificanceResult(statistic=np.float64(0.520287877970104), pvalue=np.float64(0.0009913639098877028))

# %%
df_query = (
    df.groupby("system", as_index=False)
      .mean(numeric_only=True)
)
for corr in (stats.spearmanr, stats.pearsonr ,stats.kendalltau):
    print(corr.__name__, corr(df_query[accuracy], df_query[quality]))
# Out:
# spearmanr SignificanceResult(statistic=np.float64(0.6857142857142857), pvalue=np.float64(0.0006008432641126349))
# pearsonr PearsonRResult(statistic=np.float64(0.916169310201368), pvalue=np.float64(5.5775905522956724e-09))
# kendalltau SignificanceResult(statistic=np.float64(0.5238095238095238), pvalue=np.float64(0.0006175346201348531))

# %%
df.query(f"direction == 'en_es'")
# Out:
#    direction             system  SacreBLEU     chrF  XCOMET  XCOMET-QE  \
# 0      en_es     phi4multimodal    34.4661  59.9712  0.8743     0.9074
# 1      en_es  tower_owsm4.0-ctc    40.8784  65.8513  0.8982     0.9081
# 2      en_es  gemma_owsm4.0-ctc    36.7737  63.3315  0.8978     0.9060
# 3      en_es        owsm4.0-ctc    26.2753  56.4295  0.6228     0.6461
# 4      en_es  gemma_seamlessm4t    37.7337  63.6069  0.9082     0.9152
# 5      en_es      qwen2audio-7b    34.0208  60.8791  0.8366     0.8506
# 6      en_es      gemma_whisper    36.7579  63.5633  0.9138     0.9201
# 7      en_es    aya_seamlessm4t    39.6437  64.8979  0.9085     0.9191
# 8      en_es        aya_whisper    38.4016  64.6000  0.9122     0.9231
# 9      en_es    tower_canary-v2    41.7574  66.5590  0.9232     0.9332
# 10     en_es   gemini-2.5-flash    39.8746  65.7316  0.9061     0.9114
# 11     en_es        seamlessm4t    31.3890  59.2218  0.8200     0.8493
# 12     en_es          desta2-8b     3.0622  23.7473  0.6316     0.6453
# 13     en_es    aya_owsm4.0-ctc    38.4306  64.4510  0.9001     0.9121
# 14     en_es  tower_seamlessm4t    38.2746  65.8591  0.9095     0.9186
# 15     en_es  voxtral-small-24b    40.0541  64.8776  0.9183     0.9273
# 16     en_es            spirelm    39.2655  64.1955  0.8315     0.8454
# 17     en_es          canary-v2    40.1882  65.3243  0.9096     0.9219
# 18     en_es      tower_whisper    40.6209  65.9956  0.9131     0.9212
# 19     en_es    gemma_canary-v2    37.3377  63.7896  0.9203     0.9275
# 20     en_es      aya_canary-v2    39.1632  65.0512  0.9228     0.9326
#
#     RefMetricX_24  QEMetricX_24  LinguaPy  RefMetricX_24-Strict-linguapy  \
# 0          6.0917        5.7666   16.1010                         6.8949
# 1          3.0785        2.9667    0.5525                         3.1920
# 2          2.9787        2.8223    0.4736                         3.0710
# 3         10.3550        9.8981    1.1839                        10.5336
# 4          2.7379        2.5957    0.5525                         2.8440
# 5          4.1566        3.9188    1.4207                         4.3595
# 6          2.6134        2.4725    0.3157                         2.6870
# 7          2.7008        2.5798    0.7103                         2.8482
# 8          2.6222        2.4667    0.5525                         2.7469
# 9          2.4157        2.2819    0.5525                         2.5301
# 10         2.8876        2.7341    0.6314                         3.0216
# 11         6.0142        5.6253    1.6575                         6.1468
# 12         8.2209        8.1136    1.5785                         8.3774
# 13         2.9594        2.7992    0.5525                         3.0814
# 14         2.7713        2.6740    0.5525                         2.8848
# 15         2.4991        2.3932    0.3946                         2.5893
# 16         4.2327        4.0475    0.4736                         4.3123
# 17         2.8024        2.6701    0.6314                         2.9396
# 18         2.6718        2.5465    0.6314                         2.8132
# 19         2.4533        2.2686    0.4736                         2.5521
# 20         2.4176        2.2518    0.6314                         2.5369
#
#     QEMetricX_24-Strict-linguapy  XCOMET-Strict-linguapy  \
# 0                         6.7201                  0.7519
# 1                         3.0793                  0.8938
# 2                         2.9170                  0.8944
# 3                        10.0779                  0.6162
# 4                         2.7020                  0.9047
# 5                         4.1261                  0.8271
# 6                         2.5405                  0.9116
# 7                         2.7263                  0.9030
# 8                         2.5888                  0.9082
# 9                         2.3942                  0.9191
# 10                        2.8710                  0.9009
# 11                        5.7721                  0.8099
# 12                        8.2901                  0.6265
# 13                        2.9219                  0.8956
# 14                        2.7872                  0.9053
# 15                        2.4756                  0.9149
# 16                        4.1282                  0.8285
# 17                        2.8018                  0.9050
# 18                        2.6871                  0.9079
# 19                        2.3610                  0.9170
# 20                        2.3724                  0.9194
#
#     XCOMET-QE-Strict-linguapy  accuracy_ne  accuracy_term  accuracy_ci_ne  \
# 0                      0.7630     0.626374       0.712998        0.661783
# 1                      0.9037     0.677656       0.815928        0.733822
# 2                      0.9023     0.655678       0.787002        0.703907
# 3                      0.6390     0.465201       0.699850        0.489621
# 4                      0.9114     0.702076       0.788881        0.741758
# 5                      0.8396     0.654457       0.740796        0.697802
# 6                      0.9178     0.676435       0.784373        0.731990
# 7                      0.9134     0.705128       0.813298        0.747863
# 8                      0.9182     0.677045       0.808039        0.752747
# 9                      0.9290     0.709402       0.827198        0.757021
# 10                     0.9060     0.677656       0.824944        0.763736
# 11                     0.8373     0.655678       0.756198        0.694750
# 12                     0.6406     0.457875       0.542825        0.529915
# 13                     0.9072     0.664225       0.811796        0.721612
# 14                     0.9144     0.711844       0.826071        0.758852
# 15                     0.9240     0.697192       0.796018        0.760073
# 16                     0.8425     0.689255       0.779489        0.715507
# 17                     0.9167     0.695971       0.802404        0.729548
# 18                     0.9156     0.689866       0.815928        0.755189
# 19                     0.9241     0.689866       0.799775        0.728938
# 20                     0.9286     0.700855       0.820060        0.743590
#
#     accuracy_ci_term
# 0           0.731405
# 1           0.825695
# 2           0.794891
# 3           0.710368
# 4           0.794515
# 5           0.754696
# 6           0.796018
# 7           0.820811
# 8           0.820811
# 9           0.833959
# 10          0.832081
# 11          0.765214
# 12          0.552592
# 13          0.821187
# 14          0.833584
# 15          0.814801
# 16          0.785500
# 17          0.812171
# 18          0.825319
# 19          0.804658
# 20          0.828700

# %%
import scipy.stats as stats

#Collapse and get the metrics balanced by the linguapy score
for pair in DIRECTION_PAIRS:
    print(pair)
    sub_df = df[df['direction']==pair]
    sub_df = compute_strict_scores(sub_df)

    for system in SYSTEM_NAMES:
        if system not in set(sub_df["system"]):
            print(f"{system} not in {pair}")
            sub_df.loc[len(sub_df)+1] = None
            sub_df.loc[len(sub_df), "system"] = system
    sub_df.to_csv(f"neuroparl-st_{pair}.csv",index=False)
    df_euro = pd.read_csv(f"../europarl_st/europarl-st_{pair}.csv")
# Out:
# en_es
# whisper not in en_es
# en_fr
# whisper not in en_fr
# en_it
# whisper not in en_it

# %%
# !python3 combine_csv.py -i neuroparl-st*.csv -oc combined.csv -ot neuroparl-st.tex
# Out:
# en-es {'accuracy_ne': 70.08547008547008, 'accuracy_term': 82.00601051840721}
# en-es {'accuracy_ne': 66.42246642246641, 'accuracy_term': 81.17956423741548}
# en-es {'accuracy_ne': 70.51282051282051, 'accuracy_term': 81.32982719759579}
# en-es {'accuracy_ne': 67.70451770451771, 'accuracy_term': 80.80390683696469}
# en-es {'accuracy_ne': 69.59706959706959, 'accuracy_term': 80.24042073628851}
# en-es {'accuracy_ne': 45.78754578754579, 'accuracy_term': 54.28249436513899}
# en-es {'accuracy_ne': 67.76556776556777, 'accuracy_term': 82.49436513899325}
# en-es {'accuracy_ne': 68.98656898656898, 'accuracy_term': 79.97746055597295}
# en-es {'accuracy_ne': 65.56776556776556, 'accuracy_term': 78.70022539444027}
# en-es {'accuracy_ne': 70.2075702075702, 'accuracy_term': 78.88805409466566}
# en-es {'accuracy_ne': 67.64346764346764, 'accuracy_term': 78.43726521412472}
# en-es {'accuracy_ne': 46.52014652014652, 'accuracy_term': 69.98497370398196}
# en-es {'accuracy_ne': 62.637362637362635, 'accuracy_term': 71.29977460555973}
# en-es {'accuracy_ne': 65.44566544566544, 'accuracy_term': 74.07963936889557}
# en-es {'accuracy_ne': 65.56776556776556, 'accuracy_term': 75.6198347107438}
# en-es {'accuracy_ne': 68.92551892551893, 'accuracy_term': 77.94891059353868}
# en-es {'accuracy_ne': 70.94017094017094, 'accuracy_term': 82.71975957926371}
# en-es {'accuracy_ne': 67.76556776556777, 'accuracy_term': 81.59278737791135}
# en-es {'accuracy_ne': 71.18437118437119, 'accuracy_term': 82.60706235912848}
# en-es {'accuracy_ne': 68.98656898656898, 'accuracy_term': 81.59278737791135}
# en-es {'accuracy_ne': 69.71916971916971, 'accuracy_term': 79.60180315552216}
# en-es {'accuracy_ne': 0.0, 'accuracy_term': 0.0}
# en-fr {'accuracy_ne': 66.19718309859155, 'accuracy_term': 81.06549032914828}
# en-fr {'accuracy_ne': 63.70038412291933, 'accuracy_term': 80.04750593824228}
# en-fr {'accuracy_ne': 65.94110115236876, 'accuracy_term': 79.94570749915168}
# en-fr {'accuracy_ne': 66.64532650448145, 'accuracy_term': 80.01357312521208}
# en-fr {'accuracy_ne': 66.38924455825864, 'accuracy_term': 81.09942314217848}
# en-fr {'accuracy_ne': 43.9820742637644, 'accuracy_term': 53.919239904988125}
# en-fr {'accuracy_ne': 67.09346991037131, 'accuracy_term': 82.42280285035629}
# en-fr {'accuracy_ne': 64.9167733674776, 'accuracy_term': 78.07940278249067}
# en-fr {'accuracy_ne': 62.29193341869398, 'accuracy_term': 77.06141839158465}
# en-fr {'accuracy_ne': 64.9807938540333, 'accuracy_term': 76.72209026128266}
# en-fr {'accuracy_ne': 65.68501920614597, 'accuracy_term': 77.29894808279606}
# en-fr {'accuracy_ne': 42.18950064020486, 'accuracy_term': 67.119104173736}
# en-fr {'accuracy_ne': 45.26248399487836, 'accuracy_term': 55.34441805225653}
# en-fr {'accuracy_ne': 62.355953905249685, 'accuracy_term': 77.12928401764506}
# en-fr {'accuracy_ne': 59.53905249679897, 'accuracy_term': 72.71801832371904}
# en-fr {'accuracy_ne': 65.55697823303457, 'accuracy_term': 76.34882931795046}
# en-fr {'accuracy_ne': 68.24583866837388, 'accuracy_term': 82.32100441126569}
# en-fr {'accuracy_ne': 65.87708066581305, 'accuracy_term': 82.32100441126569}
# en-fr {'accuracy_ne': 67.9257362355954, 'accuracy_term': 82.2531387852053}
# en-fr {'accuracy_ne': 68.24583866837388, 'accuracy_term': 82.04954190702409}
# en-fr {'accuracy_ne': 66.90140845070422, 'accuracy_term': 82.4567356633865}
# en-fr {'accuracy_ne': 0.0, 'accuracy_term': 0.0}
# en-it {'accuracy_ne': 61.174551386623165, 'accuracy_term': 77.45415318230853}
# en-it {'accuracy_ne': 58.2537517053206, 'accuracy_term': 77.29336966394187}
# en-it {'accuracy_ne': 61.45975443383356, 'accuracy_term': 78.42870118074478}
# en-it {'accuracy_ne': 60.91405184174625, 'accuracy_term': 76.70299727520435}
# en-it {'accuracy_ne': 62.82401091405184, 'accuracy_term': 76.43051771117166}
# en-it {'accuracy_ne': 41.20054570259209, 'accuracy_term': 48.09264305177112}
# en-it {'accuracy_ne': 62.68758526603001, 'accuracy_term': 79.51861943687557}
# en-it {'accuracy_ne': 59.95907230559345, 'accuracy_term': 75.4314259763851}
# en-it {'accuracy_ne': 57.094133697135064, 'accuracy_term': 75.29518619436875}
# en-it {'accuracy_ne': 59.754433833560704, 'accuracy_term': 76.20345140781109}
# en-it {'accuracy_ne': 59.276944065484315, 'accuracy_term': 73.97820163487738}
# en-it {'accuracy_ne': 40.586630286493865, 'accuracy_term': 56.902815622161675}
# en-it {'accuracy_ne': 55.04774897680764, 'accuracy_term': 69.70935513169846}
# en-it {'accuracy_ne': 60.16371077762619, 'accuracy_term': 68.7102633969119}
# en-it {'accuracy_ne': 58.663028649386085, 'accuracy_term': 65.12261580381471}
# en-it {'accuracy_ne': 65.00682128240109, 'accuracy_term': 73.433242506812}
# en-it {'accuracy_ne': 63.915416098226466, 'accuracy_term': 78.33787465940054}
# en-it {'accuracy_ne': 61.59618008185539, 'accuracy_term': 78.06539509536785}
# en-it {'accuracy_ne': 63.5743519781719, 'accuracy_term': 78.88283378746594}
# en-it {'accuracy_ne': 63.43792633015006, 'accuracy_term': 77.52043596730245}
# en-it {'accuracy_ne': 64.12005457025921, 'accuracy_term': 76.83923705722071}
# en-it {'accuracy_ne': 0.0, 'accuracy_term': 0.0}
# dict_keys(['en-es', 'en-fr', 'en-it'])
# ['en-es', 'en-fr', 'en-it']
# whisper en-es accuracy_ne
# 0.0
# whisper en-es accuracy_term
# 0.0
# whisper en-fr accuracy_ne
# 0.0
# whisper en-fr accuracy_term
# 0.0
# whisper en-it accuracy_ne
# 0.0
# whisper en-it accuracy_term
# 0.0
# seamlessm4t en-es accuracy_ne
# 65.56776556776556
# seamlessm4t en-es accuracy_term
# 75.6198347107438
# seamlessm4t en-fr accuracy_ne
# 59.53905249679897
# seamlessm4t en-fr accuracy_term
# 72.71801832371904
# seamlessm4t en-it accuracy_ne
# 58.663028649386085
# seamlessm4t en-it accuracy_term
# 65.12261580381471
# canary-v2 en-es accuracy_ne
# 69.59706959706959
# canary-v2 en-es accuracy_term
# 80.24042073628851
# canary-v2 en-fr accuracy_ne
# 66.38924455825864
# canary-v2 en-fr accuracy_term
# 81.09942314217848
# canary-v2 en-it accuracy_ne
# 62.82401091405184
# canary-v2 en-it accuracy_term
# 76.43051771117166
# owsm4.0-ctc en-es accuracy_ne
# 46.52014652014652
# owsm4.0-ctc en-es accuracy_term
# 69.98497370398196
# owsm4.0-ctc en-fr accuracy_ne
# 42.18950064020486
# owsm4.0-ctc en-fr accuracy_term
# 67.119104173736
# owsm4.0-ctc en-it accuracy_ne
# 40.586630286493865
# owsm4.0-ctc en-it accuracy_term
# 56.902815622161675
# aya whisper en-es accuracy_ne
# 67.70451770451771
# aya whisper en-es accuracy_term
# 80.80390683696469
# aya whisper en-fr accuracy_ne
# 66.64532650448145
# aya whisper en-fr accuracy_term
# 80.01357312521208
# aya whisper en-it accuracy_ne
# 60.91405184174625
# aya whisper en-it accuracy_term
# 76.70299727520435
# gemma whisper en-es accuracy_ne
# 67.64346764346764
# gemma whisper en-es accuracy_term
# 78.43726521412472
# gemma whisper en-fr accuracy_ne
# 65.68501920614597
# gemma whisper en-fr accuracy_term
# 77.29894808279606
# gemma whisper en-it accuracy_ne
# 59.276944065484315
# gemma whisper en-it accuracy_term
# 73.97820163487738
# tower whisper en-es accuracy_ne
# 68.98656898656898
# tower whisper en-es accuracy_term
# 81.59278737791135
# tower whisper en-fr accuracy_ne
# 68.24583866837388
# tower whisper en-fr accuracy_term
# 82.04954190702409
# tower whisper en-it accuracy_ne
# 63.43792633015006
# tower whisper en-it accuracy_term
# 77.52043596730245
# aya seamlessm4t en-es accuracy_ne
# 70.51282051282051
# aya seamlessm4t en-es accuracy_term
# 81.32982719759579
# aya seamlessm4t en-fr accuracy_ne
# 65.94110115236876
# aya seamlessm4t en-fr accuracy_term
# 79.94570749915168
# aya seamlessm4t en-it accuracy_ne
# 61.45975443383356
# aya seamlessm4t en-it accuracy_term
# 78.42870118074478
# gemma seamlessm4t en-es accuracy_ne
# 70.2075702075702
# gemma seamlessm4t en-es accuracy_term
# 78.88805409466566
# gemma seamlessm4t en-fr accuracy_ne
# 64.9807938540333
# gemma seamlessm4t en-fr accuracy_term
# 76.72209026128266
# gemma seamlessm4t en-it accuracy_ne
# 59.754433833560704
# gemma seamlessm4t en-it accuracy_term
# 76.20345140781109
# tower seamlessm4t en-es accuracy_ne
# 71.18437118437119
# tower seamlessm4t en-es accuracy_term
# 82.60706235912848
# tower seamlessm4t en-fr accuracy_ne
# 67.9257362355954
# tower seamlessm4t en-fr accuracy_term
# 82.2531387852053
# tower seamlessm4t en-it accuracy_ne
# 63.5743519781719
# tower seamlessm4t en-it accuracy_term
# 78.88283378746594
# aya canary-v2 en-es accuracy_ne
# 70.08547008547008
# aya canary-v2 en-es accuracy_term
# 82.00601051840721
# aya canary-v2 en-fr accuracy_ne
# 66.19718309859155
# aya canary-v2 en-fr accuracy_term
# 81.06549032914828
# aya canary-v2 en-it accuracy_ne
# 61.174551386623165
# aya canary-v2 en-it accuracy_term
# 77.45415318230853
# gemma canary-v2 en-es accuracy_ne
# 68.98656898656898
# gemma canary-v2 en-es accuracy_term
# 79.97746055597295
# gemma canary-v2 en-fr accuracy_ne
# 64.9167733674776
# gemma canary-v2 en-fr accuracy_term
# 78.07940278249067
# gemma canary-v2 en-it accuracy_ne
# 59.95907230559345
# gemma canary-v2 en-it accuracy_term
# 75.4314259763851
# tower canary-v2 en-es accuracy_ne
# 70.94017094017094
# tower canary-v2 en-es accuracy_term
# 82.71975957926371
# tower canary-v2 en-fr accuracy_ne
# 68.24583866837388
# tower canary-v2 en-fr accuracy_term
# 82.32100441126569
# tower canary-v2 en-it accuracy_ne
# 63.915416098226466
# tower canary-v2 en-it accuracy_term
# 78.33787465940054
# aya owsm4.0-ctc en-es accuracy_ne
# 66.42246642246641
# aya owsm4.0-ctc en-es accuracy_term
# 81.17956423741548
# aya owsm4.0-ctc en-fr accuracy_ne
# 63.70038412291933
# aya owsm4.0-ctc en-fr accuracy_term
# 80.04750593824228
# aya owsm4.0-ctc en-it accuracy_ne
# 58.2537517053206
# aya owsm4.0-ctc en-it accuracy_term
# 77.29336966394187
# gemma owsm4.0-ctc en-es accuracy_ne
# 65.56776556776556
# gemma owsm4.0-ctc en-es accuracy_term
# 78.70022539444027
# gemma owsm4.0-ctc en-fr accuracy_ne
# 62.29193341869398
# gemma owsm4.0-ctc en-fr accuracy_term
# 77.06141839158465
# gemma owsm4.0-ctc en-it accuracy_ne
# 57.094133697135064
# gemma owsm4.0-ctc en-it accuracy_term
# 75.29518619436875
# tower owsm4.0-ctc en-es accuracy_ne
# 67.76556776556777
# tower owsm4.0-ctc en-es accuracy_term
# 81.59278737791135
# tower owsm4.0-ctc en-fr accuracy_ne
# 65.87708066581305
# tower owsm4.0-ctc en-fr accuracy_term
# 82.32100441126569
# tower owsm4.0-ctc en-it accuracy_ne
# 61.59618008185539
# tower owsm4.0-ctc en-it accuracy_term
# 78.06539509536785
# desta2-8b en-es accuracy_ne
# 45.78754578754579
# desta2-8b en-es accuracy_term
# 54.28249436513899
# desta2-8b en-fr accuracy_ne
# 43.9820742637644
# desta2-8b en-fr accuracy_term
# 53.919239904988125
# desta2-8b en-it accuracy_ne
# 41.20054570259209
# desta2-8b en-it accuracy_term
# 48.09264305177112
# qwen2audio-7b en-es accuracy_ne
# 65.44566544566544
# qwen2audio-7b en-es accuracy_term
# 74.07963936889557
# qwen2audio-7b en-fr accuracy_ne
# 62.355953905249685
# qwen2audio-7b en-fr accuracy_term
# 77.12928401764506
# qwen2audio-7b en-it accuracy_ne
# 60.16371077762619
# qwen2audio-7b en-it accuracy_term
# 68.7102633969119
# phi4multimodal en-es accuracy_ne
# 62.637362637362635
# phi4multimodal en-es accuracy_term
# 71.29977460555973
# phi4multimodal en-fr accuracy_ne
# 45.26248399487836
# phi4multimodal en-fr accuracy_term
# 55.34441805225653
# phi4multimodal en-it accuracy_ne
# 55.04774897680764
# phi4multimodal en-it accuracy_term
# 69.70935513169846
# voxtral-small-24b en-es accuracy_ne
# 69.71916971916971
# voxtral-small-24b en-es accuracy_term
# 79.60180315552216
# voxtral-small-24b en-fr accuracy_ne
# 66.90140845070422
# voxtral-small-24b en-fr accuracy_term
# 82.4567356633865
# voxtral-small-24b en-it accuracy_ne
# 64.12005457025921
# voxtral-small-24b en-it accuracy_term
# 76.83923705722071
# spirelm en-es accuracy_ne
# 68.92551892551893
# spirelm en-es accuracy_term
# 77.94891059353868
# spirelm en-fr accuracy_ne
# 65.55697823303457
# spirelm en-fr accuracy_term
# 76.34882931795046
# spirelm en-it accuracy_ne
# 65.00682128240109
# spirelm en-it accuracy_term
# 73.433242506812
# gemini-2.5-flash en-es accuracy_ne
# 67.76556776556777
# gemini-2.5-flash en-es accuracy_term
# 82.49436513899325
# gemini-2.5-flash en-fr accuracy_ne
# 67.09346991037131
# gemini-2.5-flash en-fr accuracy_term
# 82.42280285035629
# gemini-2.5-flash en-it accuracy_ne
# 62.68758526603001
# gemini-2.5-flash en-it accuracy_term
# 79.51861943687557
